# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython import display
import warnings
import seaborn as sns
import ehrapy as ep
import anndata as ad

plt.style.use("ggplot")
warnings.filterwarnings("ignore")
from tableone import TableOne

# %%
adata = ep.io.read_csv("./notebooks/ehrapy_data/final_icu.csv.gz", index_column = 'stay_id') 

adata2 = ep.io.read_csv("./notebooks/ehrapy_data/icu_stay_diag.csv.gz")

# %%
adata
# we have 9864 unique icu_stays and 166 features
# Out:
# AnnData object with n_obs × n_vars = 9864 × 164
#     obs: 'intime', 'outtime'
#     layers: 'original'

# %%
data = adata.to_df()
data.index = data.index.astype(int)

# %%
adata.to_df().head()
# Out:
#          subject_id Age gender  \
# stay_id
# 30000484   18421337  91      M
# 30000831   15726459  78      M
# 30002498   17938576  59      M
# 30003598   15332791  64      F
# 30004320   17686783  52      F
#
#                         ethnicity insurance  \
# stay_id
# 30000484  MULTIPLE RACE/ETHNICITY  Medicare
# 30000831                    WHITE   Private
# 30002498                    WHITE  Medicare
# 30003598                    WHITE  Medicare
# 30004320                    WHITE   Private
#
#          hospital_death  \
# stay_id
# 30000484              0
# 30000831              0
# 30002498              0
# 30003598              0
# 30004320              0
#
#                           dod   hadm_id  \
# stay_id
# 30000484  2136-02-21 00:00:00  22413411
# 30000831                    0  22744101
# 30002498  2160-11-25 00:00:00  20818145
# 30003598                    0  20683754
# 30004320  2172-02-13 00:00:00  22994815
#
#                  los has_E87  ...  \
# stay_id                       ...
# 30000484   59.493333       0  ...
# 30000831   64.923333       1  ...
# 30002498   25.601111       0  ...
# 30003598  115.504444       0  ...
# 30004320   24.750556       0  ...
#
#          MORGANELLA MORGANII_positive  \
# stay_id
# 30000484                            0
# 30000831                            0
# 30002498                            0
# 30003598                            0
# 30004320                            0
#
#          NON-FERMENTER, NOT PSEUDOMONAS AERUGINOSA_positive  \
# stay_id
# 30000484                                                  0
# 30000831                                                  0
# 30002498                                                  0
# 30003598                                                  0
# 30004320                                                  0
#
#          STREPTOCOCCUS ANGINOSUS (MILLERI) GROUP_positive  \
# stay_id
# 30000484                                                0
# 30000831                                                0
# 30002498                                                0
# 30003598                                                0
# 30004320                                                0
#
#          SERRATIA MARCESCENS_positive  \
# stay_id
# 30000484                            0
# 30000831                            0
# 30002498                            0
# 30003598                            0
# 30004320                            0
#
#          CANDIDA ALBICANS_positive  \
# stay_id
# 30000484                         0
# 30000831                         0
# 30002498                         0
# 30003598                         0
# 30004320                         0
#
#          CLOSTRIDIUM DIFFICILE_positive  \
# stay_id
# 30000484                              0
# 30000831                              0
# 30002498                              0
# 30003598                     2189-04-28
# 30004320                              0
#
#          CANDIDA ALBICANS, PRESUMPTIVE IDENTIFICATION_positive  \
# stay_id
# 30000484                                                  0
# 30000831                                                  0
# 30002498                                                  0
# 30003598                                                  0
# 30004320                                                  0
#
#          ACHROMOBACTER SP._positive  \
# stay_id
# 30000484                          0
# 30000831                          0
# 30002498                          0
# 30003598                          0
# 30004320                          0
#
#          STAPH AUREUS COAG +_positive  \
# stay_id
# 30000484                            0
# 30000831                            0
# 30002498                            0
# 30003598                   2189-04-14
# 30004320                            0
#
#          ACINETOBACTER BAUMANNII COMPLEX_positive
# stay_id
# 30000484                                        0
# 30000831                                        0
# 30002498                                        0
# 30003598                                        0
# 30004320                                        0
#
# [5 rows x 164 columns]

# %%
print(f"Number of ICU stays: {str(len(data.index.unique()))}")
print(f"Number of survivors: {str(len(data[data['hospital_death']==0].index.unique()))}")
print(f"Number of non-survivors: {str(len(data[data['hospital_death']==1].index.unique()))}")
print(
    f"Mortality: {str(round(100*len(data[data['hospital_death']==1].index.unique()) / len(data.index.unique()),1))}%"
)
# Out:
# Number of ICU stays: 9864
# Number of survivors: 8514
# Number of non-survivors: 1350
# Mortality: 13.7%

# %% [markdown]
# https://ehrapy.readthedocs.io/en/stable/tutorials/notebooks/ml_usecases.html

# %%
adata.obs["mortality_cat"] = adata[:, "hospital_death"].X.flatten()

# %%
adata.obs["mortality_cat"] = adata[:, "hospital_death"].X
adata.obs["mortality_cat"] = adata.obs["mortality_cat"].astype(int).astype(str)
adata.obs["stay_id"] = adata.obs.index.astype(int)
adata

# %% [markdown]
# https://ehrapy.readthedocs.io/en/stable/tutorials/notebooks/ml_usecases.html

# %%
adata_per_patient = ep.ad.df_to_anndata(data.groupby(["stay_id"]).mean())
adata_per_patient
# Out:
# ----------------------------------------------
#
# TypeError    Traceback (most recent call last)
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#
#    1941 try:
#
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#
#    1943 except Exception as err:
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#
#     862     preserve_dtype = True
#
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#
#     884 for i, group in enumerate(splitter):
#
# --> 885     res = func(group)
#
#     886     res = extract_result(res)
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:2454, in GroupBy.mean.<locals>.<lambda>(x)
#
#    2451 else:
#
#    2452     result = self._cython_agg_general(
#
#    2453         "mean",
#
# -> 2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#
#    2455         numeric_only=numeric_only,
#
#    2456     )
#
#    2457     return result.__finalize__(self.obj, method="groupby")
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\pandas\core\series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#
#    6541 @doc(make_doc("mean", ndim=1))
#
#    6542 def mean(
#
#    6543     self,
#
#    (...)   6547     **kwargs,
#
#    6548 ):
#
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
#   12413 def mean(
#
#   12414     self,
#
#   12415     axis: Axis | None = 0,
#
#    (...)  12418     **kwargs,
#
#   12419 ) -> Series | float:
#
# > 12420     return self._stat_function(
#
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#
#   12422     )
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\pandas\core\generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#
# > 12377 return self._reduce(
#
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#
#   12379 )
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\pandas\core\series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#
#    6453     raise TypeError(
#
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#
#    6455         "with non-numeric dtypes."
#
#    6456     )
#
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#
#     146 else:
#
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#
#     149 return result
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#
#     402     mask = isna(values)
#
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#
#     406 if datetimelike:
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
#
# --> 720 the_sum = _ensure_numeric(the_sum)
#
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#
#    1699 if isinstance(x, str):
#
#    1700     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
#
# -> 1701     raise TypeError(f"Could not convert string '{x}' to numeric")
#
#    1702 try:
#
#
#
# TypeError: Could not convert string 'M' to numeric
#
#
#
# The above exception was the direct cause of the following exception:
#
#
#
# TypeError    Traceback (most recent call last)
#
# Cell In[58], line 1
#
# ----> 1 adata_per_patient = ep.ad.df_to_anndata(data.groupby(["stay_id"]).mean())
#
#       2 adata_per_patient
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:2452, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#
#    2445     return self._numba_agg_general(
#
#    2446         grouped_mean,
#
#    2447         executor.float_dtype_mapping,
#
#    2448         engine_kwargs,
#
#    2449         min_periods=0,
#
#    2450     )
#
#    2451 else:
#
# -> 2452     result = self._cython_agg_general(
#
#    2453         "mean",
#
#    2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#
#    2455         numeric_only=numeric_only,
#
#    2456     )
#
#    2457     return result.__finalize__(self.obj, method="groupby")
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1998, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#
#    1995     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#
#    1996     return result
#
# -> 1998 new_mgr = data.grouped_reduce(array_func)
#
#    1999 res = self._wrap_agged_manager(new_mgr)
#
#    2000 if how in ["idxmin", "idxmax"]:
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\pandas\core\internals\managers.py:1469, in BlockManager.grouped_reduce(self, func)
#
#    1465 if blk.is_object:
#
#    1466     # split on object-dtype blocks bc some columns may raise
#
#    1467     #  while others do not.
#
#    1468     for sb in blk._split():
#
# -> 1469         applied = sb.apply(func)
#
#    1470         result_blocks = extend_blocks(applied, result_blocks)
#
#    1471 else:
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\pandas\core\internals\blocks.py:393, in Block.apply(self, func, **kwargs)
#
#     387 @final
#
#     388 def apply(self, func, **kwargs) -> list[Block]:
#
#     389     """
#
#     390     apply the function to my values; return a block if we are not
#
#     391     one
#
#     392     """
#
# --> 393     result = func(self.values, **kwargs)
#
#     395     result = maybe_coerce_values(result)
#
#     396     return self._split_op_result(result)
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1995, in GroupBy._cython_agg_general.<locals>.array_func(values)
#
#    1992     return result
#
#    1994 assert alt is not None
#
# -> 1995 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#
#    1996 return result
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1946, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#
#    1944     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#
#    1945     # preserve the kind of exception that raised
#
# -> 1946     raise type(err)(msg) from err
#
#    1948 if ser.dtype == object:
#
#    1949     res_values = res_values.astype(object, copy=False)
#
#
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
# let's try ehrapy's infer feature types
ep.ad.infer_feature_types(adata)
# Out:
# ! Features 'hospital_death', 'has_E87', 'has_J18', 'has_I50', 'has_N17', 'has_J96', 'has_E11', 'has_I25', 'has_E78', 'has_J98', 'has_Z51', 'has_I47', 'has_I10', 'has_D64', 'has_Z95', 'has_N18', 'proc_224277', 'proc_224275', 'proc_225402', 'proc_225432', 'proc_224263', 'proc_227194', 'proc_225401', 'proc_225459', 'proc_225752', 'proc_224264', 'proc_224274', 'proc_228129', 'proc_225454', 'proc_228128', 'proc_229351', 'proc_225792', 'proc_225400', 'proc_221217', 'proc_225966', 'proc_225451', 'proc_221214', 'proc_224385', 'proc_229581' were detected as categorical features stored numerically.Please verify and correct using `ep.ad.replace_feature_types` if necessary.
#  Detected feature types for AnnData object
# with 9864 obs and 166 vars
# ├── 📅 Date features
# ├── 📐 Numerical features
# │   ├── ACD-A Citrate (1000ml)
# │   ├── ACD-A Citrate (500ml)
# │   ├── Acetaminophen-IV
# │   ├── Acetylcysteine
# │   ├── Age
# │   ├── Alteplase (TPA)
# │   ├── Aminocaproic acid (Amicar)
# │   ├── Aminophylline
# │   ├── Amiodarone
# │   ├── Amiodarone 150/100
# │   ├── Amiodarone 450/250
# │   ├── Amiodarone 600/500
# │   ├── Angiotensin II (Giapreza)
# │   ├── Argatroban
# │   ├── Bivalirudin (Angiomax)
# │   ├── Bumetanide (Bumex)
# │   ├── Calcium Chloride
# │   ├── Calcium Gluconate (Bolus)
# │   ├── Calcium Gluconate (CRRT)
# │   ├── Cisatracurium
# │   ├── Clevidipine (Cleviprex)
# │   ├── Cyclosporine
# │   ├── Dexmedetomidine (Precedex)
# │   ├── Dilantin
# │   ├── Diltiazem
# │   ├── Dobutamine
# │   ├── Dopamine
# │   ├── Epinephrine
# │   ├── Epoprostenol (Veletri)
# │   ├── Eptifibatide (Integrilin)
# │   ├── Esmolol
# │   ├── Fentanyl
# │   ├── Fentanyl (Concentrate)
# │   ├── Fosphenytoin
# │   ├── Furosemide (Lasix)
# │   ├── Furosemide (Lasix) 250/50
# │   ├── Heparin Sodium
# │   ├── Heparin Sodium (CRRT-Prefilter)
# │   ├── Heparin Sodium (Impella)
# │   ├── Hydromorphone (Dilaudid)
# │   ├── Insulin - Regular
# │   ├── Isuprel
# │   ├── KCL (Bolus)
# │   ├── KCl (CRRT)
# │   ├── Ketamine
# │   ├── Labetalol
# │   ├── Lepirudin
# │   ├── Levetiracetam (Keppra)
# │   ├── Lidocaine
# │   ├── Lorazepam (Ativan)
# │   ├── Magnesium Sulfate (Bolus)
# │   ├── Magnesium Sulfate (OB-GYN)
# │   ├── Mannitol
# │   ├── Methadone Hydrochloride
# │   ├── Midazolam (Versed)
# │   ├── Milrinone
# │   ├── Morphine Sulfate
# │   ├── Mycophenolate mofetil (Cellcept)
# │   ├── Naloxone (Narcan)
# │   ├── Nesiritide
# │   ├── Nicardipine
# │   ├── Nicardipine 40mg/200
# │   ├── Nitroglycerin
# │   ├── Nitroprusside
# │   ├── Norepinephrine
# │   ├── Octreotide
# │   ├── Pantoprazole (Protonix)
# │   ├── Pentobarbital
# │   ├── Phenylephrine
# │   ├── Phenylephrine (200/250)
# │   ├── Phenylephrine (50/250)
# │   ├── Procainamide
# │   ├── Propofol
# │   ├── Rocuronium
# │   ├── Tirofiban (Aggrastat)
# │   ├── Treprostinil (Remodulin)
# │   ├── Unnamed: 0
# │   ├── Vasopressin
# │   ├── Vecuronium
# │   ├── hadm_id
# │   ├── los
# │   ├── stay_id
# │   └── subject_id
# └── 🗂️ Categorical features
#     ├── ACHROMOBACTER SP._positive (9
#     │   categories)
#     ├── ACINETOBACTER BAUMANNII
#     │   COMPLEX_positive (26 categories)
#     ├── ACINETOBACTER BAUMANNII_positive (10
#     │   categories)
#     ├── ALCALIGENES SPECIES_positive (7
#     │   categories)
#     ├── BACTEROIDES FRAGILIS GROUP_positive
#     │   (44 categories)
#     ├── BETA STREPTOCOCCUS GROUP B_positive
#     │   (23 categories)
#     ├── CANDIDA ALBICANS, PRESUMPTIVE
#     │   IDENTIFICATION_positive (67
#     │   categories)
#     ├── CANDIDA ALBICANS_positive (97
#     │   categories)
#     ├── CANDIDA GLABRATA_positive (49
#     │   categories)
#     ├── CITROBACTER FREUNDII COMPLEX_positive
#     │   (23 categories)
#     ├── CITROBACTER KOSERI_positive (13
#     │   categories)
#     ├── CLOSTRIDIUM DIFFICILE_positive (196
#     │   categories)
#     ├── CORYNEBACTERIUM SPECIES
#     │   (DIPHTHEROIDS)_positive (71
#     │   categories)
#     ├── ENTEROBACTER AEROGENES_positive (32
#     │   categories)
#     ├── ENTEROBACTER ASBURIAE_positive (5
#     │   categories)
#     ├── ENTEROBACTER CLOACAE COMPLEX_positive
#     │   (56 categories)
#     ├── ENTEROBACTER CLOACAE_positive (22
#     │   categories)
#     ├── ENTEROCOCCUS FAECALIS_positive (49
#     │   categories)
#     ├── ENTEROCOCCUS FAECIUM_positive (126
#     │   categories)
#     ├── ENTEROCOCCUS SP._positive (342
#     │   categories)
#     ├── ESCHERICHIA COLI_positive (342
#     │   categories)
#     ├── GRAM POSITIVE BACTERIA_positive (64
#     │   categories)
#     ├── HAFNIA ALVEI_positive (7 categories)
#     ├── KLEBSIELLA OXYTOCA_positive (34
#     │   categories)
#     ├── KLEBSIELLA PNEUMONIAE_positive (186
#     │   categories)
#     ├── MIXED BACTERIAL FLORA_positive (132
#     │   categories)
#     ├── MORGANELLA MORGANII_positive (9
#     │   categories)
#     ├── NON-FERMENTER, NOT PSEUDOMONAS
#     │   AERUGINOSA_positive (18 categories)
#     ├── POSITIVE FOR METHICILLIN RESISTANT
#     │   STAPH AUREUS_positive (395
#     │   categories)
#     ├── PROBABLE ENTEROCOCCUS_positive (53
#     │   categories)
#     ├── PROTEUS MIRABILIS_positive (75
#     │   categories)
#     ├── PSEUDOMONAS AERUGINOSA_positive (218
#     │   categories)
#     ├── SERRATIA MARCESCENS_positive (50
#     │   categories)
#     ├── STAPH AUREUS COAG +_positive (529
#     │   categories)
#     ├── STAPHYLOCOCCUS EPIDERMIDIS_positive
#     │   (46 categories)
#     ├── STENOTROPHOMONAS MALTOPHILIA_positive
#     │   (72 categories)
#     ├── STREPTOCOCCUS ANGINOSUS (MILLERI)
#     │   GROUP_positive (26 categories)
#     ├── STREPTOCOCCUS PNEUMONIAE_positive (37
#     │   categories)
#     ├── VIRIDANS STREPTOCOCCI_positive (40
#     │   categories)
#     ├── YEAST_positive (1757 categories)
#     ├── dod (4169 categories)
#     ├── ethnicity (33 categories)
#     ├── gender (2 categories)
#     ├── has_D64 (2 categories)
#     ├── has_E11 (2 categories)
#     ├── has_E78 (2 categories)
#     ├── has_E87 (2 categories)
#     ├── has_I10 (2 categories)
#     ├── has_I25 (2 categories)
#     ├── has_I47 (2 categories)
#     ├── has_I50 (2 categories)
#     ├── has_J18 (1 categories)
#     ├── has_J96 (2 categories)
#     ├── has_J98 (2 categories)
#     ├── has_N17 (2 categories)
#     ├── has_N18 (2 categories)
#     ├── has_Z51 (2 categories)
#     ├── has_Z95 (2 categories)
#     ├── hospital_death (2 categories)
#     ├── insurance (6 categories)
#     ├── proc_221214 (2 categories)
#     ├── proc_221217 (2 categories)
#     ├── proc_224263 (2 categories)
#     ├── proc_224264 (2 categories)
#     ├── proc_224274 (2 categories)
#     ├── proc_224275 (2 categories)
#     ├── proc_224277 (2 categories)
#     ├── proc_224385 (2 categories)
#     ├── proc_225400 (2 categories)
#     ├── proc_225401 (2 categories)
#     ├── proc_225402 (2 categories)
#     ├── proc_225432 (2 categories)
#     ├── proc_225451 (2 categories)
#     ├── proc_225454 (2 categories)
#     ├── proc_225459 (2 categories)
#     ├── proc_225752 (2 categories)
#     ├── proc_225792 (2 categories)
#     ├── proc_225966 (2 categories)
#     ├── proc_227194 (2 categories)
#     ├── proc_228128 (2 categories)
#     ├── proc_228129 (2 categories)
#     ├── proc_229351 (2 categories)
#     └── proc_229581 (2 categories)

# %%
adata = ep.pp.encode(adata, autodetect=True)
# Out:
# Running one-hot encoding on passed column…  …
# ----------------------------------------------
#
# TypeError    Traceback (most recent call last)
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\sklearn\utils\_encode.py:174, in _unique_python(values, return_inverse, return_counts)
#
#     172 uniques_set, missing_values = _extract_missing(uniques_set)
#
# --> 174 uniques = sorted(uniques_set)
#
#     175 uniques.extend(missing_values.to_list())
#
#
#
# TypeError: '<' not supported between instances of 'str' and 'int'
#
#
#
# During handling of the above exception, another exception occurred:
#
#
#
# TypeError    Traceback (most recent call last)
#
# Cell In[30], line 1
#
# ----> 1 adata = ep.pp.encode(adata, autodetect=True)
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\ehrapy\anndata\_feature_specifications.py:162, in check_feature_types.<locals>.wrapper(adata, *args, **kwargs)
#
#     160 if _self is not None:
#
#     161     return func(_self, adata, *args, **kwargs)
#
# --> 162 return func(adata, *args, **kwargs)
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\ehrapy\preprocessing\_encoding.py:133, in encode(adata, autodetect, encodings)
#
#     131 task = progress.add_task(f"[red]Running {encodings} on detected columns ...", total=1)
#
#     132 # encode using the desired mode
#
# --> 133 encoded_x, encoded_var_names, unencoded_var_names = single_encode_mode_switcher[encodings](  # type: ignore
#
#     134     adata,
#
#     135     encoded_x,
#
#     136     updated_obs,
#
#     137     encoded_var_names,
#
#     138     unencoded_var_names,
#
#     139     categoricals_names,
#
#     140     progress,
#
#     141     task,
#
#     142 )
#
#     143 progress.update(task, description="Updating layer originals ...")
#
#     145 # update layer content with the latest categorical encoding and the old other values
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\ehrapy\preprocessing\_encoding.py:313, in _one_hot_encoding(adata, X, updated_obs, var_names, unencoded_var_names, categories, progress, task)
#
#     310 original_values = _initial_encoding(updated_obs, categories)
#
#     311 progress.update(task, description="[bold blue]Running one-hot encoding on passed columns ...")
#
# --> 313 encoder = OneHotEncoder(handle_unknown="ignore", sparse_output=False).fit(original_values)
#
#     314 categorical_prefixes = [
#
#     315     f"ehrapycat_{category}_{str(suffix).strip()}"
#
#     316     for idx, category in enumerate(categories)
#
#     317     for suffix in encoder.categories_[idx]
#
#     318 ]
#
#     319 unencoded_prefixes = [category for idx, category in enumerate(categories) for suffix in encoder.categories_[idx]]
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#
#    1466     estimator._validate_params()
#
#    1468 with config_context(
#
#    1469     skip_parameter_validation=(
#
#    1470         prefer_skip_nested_validation or global_skip_validation
#
#    1471     )
#
#    1472 ):
#
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\sklearn\preprocessing\_encoders.py:976, in OneHotEncoder.fit(self, X, y)
#
#     957 @_fit_context(prefer_skip_nested_validation=True)
#
#     958 def fit(self, X, y=None):
#
#     959     """
#
#     960     Fit OneHotEncoder to X.
#
#     961
#
#    (...)    974         Fitted encoder.
#
#     975     """
#
# --> 976     self._fit(
#
#     977         X,
#
#     978         handle_unknown=self.handle_unknown,
#
#     979         force_all_finite="allow-nan",
#
#     980     )
#
#     981     self._set_drop_idx()
#
#     982     self._n_features_outs = self._compute_n_features_outs()
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\sklearn\preprocessing\_encoders.py:99, in _BaseEncoder._fit(self, X, handle_unknown, force_all_finite, return_counts, return_and_ignore_missing_for_infrequent)
#
#      96 Xi = X_list[i]
#
#      98 if self.categories == "auto":
#
# ---> 99     result = _unique(Xi, return_counts=compute_counts)
#
#     100     if compute_counts:
#
#     101         cats, counts = result
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\sklearn\utils\_encode.py:42, in _unique(values, return_inverse, return_counts)
#
#      11 """Helper function to find unique values with support for python objects.
#
#      12
#
#      13 Uses pure python method for object dtype, and numpy method for
#
#    (...)     39     array. Only provided if `return_counts` is True.
#
#      40 """
#
#      41 if values.dtype == object:
#
# ---> 42     return _unique_python(
#
#      43         values, return_inverse=return_inverse, return_counts=return_counts
#
#      44     )
#
#      45 # numerical
#
#      46 return _unique_np(
#
#      47     values, return_inverse=return_inverse, return_counts=return_counts
#
#      48 )
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\sklearn\utils\_encode.py:179, in _unique_python(values, return_inverse, return_counts)
#
#     177 except TypeError:
#
#     178     types = sorted(t.__qualname__ for t in set(type(v) for v in values))
#
# --> 179     raise TypeError(
#
#     180         "Encoders require their input argument must be uniformly "
#
#     181         f"strings or numbers. Got {types}"
#
#     182     )
#
#     183 ret = (uniques,)
#
#     185 if return_inverse:
#
#
#
# TypeError: Encoders require their input argument must be uniformly strings or numbers. Got ['int', 'str']

# %%
adata = ep.pp.encode(adata, encodings={"one-hot": ["service_unit", "day_icu_intime"]})

# %%
ep.ad.correct_feature_types(adata, )

# %%
obs_metric, var_metrics = ep.pp.qc_metrics(adata2)

# %%
obs_metric
# Out:
#       missing_values_abs  missing_values_pct
# 0                      0                 0.0
# 1                      0                 0.0
# 2                      0                 0.0
# 3                      0                 0.0
# 4                      0                 0.0
# ...                  ...                 ...
# 9859                   0                 0.0
# 9860                   0                 0.0
# 9861                   0                 0.0
# 9862                   0                 0.0
# 9863                   0                 0.0
#
# [9864 rows x 2 columns]

# %%
var_metrics
# Out:
#                 missing_values_abs  \
# subject_id                       0
# stay_id                          0
# Age                              0
# gender                           0
# ethnicity                        0
# insurance                        0
# hospital_death                   0
# dod                              0
# hadm_id                          0
# los                              0
# has_E87                          0
# has_J18                          0
# has_I50                          0
# has_N17                          0
# has_J96                          0
# has_E11                          0
# has_I25                          0
# has_E78                          0
# has_J98                          0
# has_Z51                          0
# has_I47                          0
# has_I10                          0
# has_D64                          0
# has_Z95                          0
# has_N18                          0
#
#                 missing_values_pct  mean  \
# subject_id                     0.0   NaN
# stay_id                        0.0   NaN
# Age                            0.0   NaN
# gender                         0.0   NaN
# ethnicity                      0.0   NaN
# insurance                      0.0   NaN
# hospital_death                 0.0   NaN
# dod                            0.0   NaN
# hadm_id                        0.0   NaN
# los                            0.0   NaN
# has_E87                        0.0   NaN
# has_J18                        0.0   NaN
# has_I50                        0.0   NaN
# has_N17                        0.0   NaN
# has_J96                        0.0   NaN
# has_E11                        0.0   NaN
# has_I25                        0.0   NaN
# has_E78                        0.0   NaN
# has_J98                        0.0   NaN
# has_Z51                        0.0   NaN
# has_I47                        0.0   NaN
# has_I10                        0.0   NaN
# has_D64                        0.0   NaN
# has_Z95                        0.0   NaN
# has_N18                        0.0   NaN
#
#                 median  standard_deviation  \
# subject_id         NaN                 NaN
# stay_id            NaN                 NaN
# Age                NaN                 NaN
# gender             NaN                 NaN
# ethnicity          NaN                 NaN
# insurance          NaN                 NaN
# hospital_death     NaN                 NaN
# dod                NaN                 NaN
# hadm_id            NaN                 NaN
# los                NaN                 NaN
# has_E87            NaN                 NaN
# has_J18            NaN                 NaN
# has_I50            NaN                 NaN
# has_N17            NaN                 NaN
# has_J96            NaN                 NaN
# has_E11            NaN                 NaN
# has_I25            NaN                 NaN
# has_E78            NaN                 NaN
# has_J98            NaN                 NaN
# has_Z51            NaN                 NaN
# has_I47            NaN                 NaN
# has_I10            NaN                 NaN
# has_D64            NaN                 NaN
# has_Z95            NaN                 NaN
# has_N18            NaN                 NaN
#
#                 min  max  iqr_outliers
# subject_id      NaN  NaN           NaN
# stay_id         NaN  NaN           NaN
# Age             NaN  NaN           NaN
# gender          NaN  NaN           NaN
# ethnicity       NaN  NaN           NaN
# insurance       NaN  NaN           NaN
# hospital_death  NaN  NaN           NaN
# dod             NaN  NaN           NaN
# hadm_id         NaN  NaN           NaN
# los             NaN  NaN           NaN
# has_E87         NaN  NaN           NaN
# has_J18         NaN  NaN           NaN
# has_I50         NaN  NaN           NaN
# has_N17         NaN  NaN           NaN
# has_J96         NaN  NaN           NaN
# has_E11         NaN  NaN           NaN
# has_I25         NaN  NaN           NaN
# has_E78         NaN  NaN           NaN
# has_J98         NaN  NaN           NaN
# has_Z51         NaN  NaN           NaN
# has_I47         NaN  NaN           NaN
# has_I10         NaN  NaN           NaN
# has_D64         NaN  NaN           NaN
# has_Z95         NaN  NaN           NaN
# has_N18         NaN  NaN           NaN

# %%
ep.settings.set_figure_params(figsize=(4, 3), dpi=100)
ep.pl.violin(adata, keys=["Age"], groupby="gender")
# Out:
# ----------------------------------------------
#
# KeyError     Traceback (most recent call last)
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#
#    3804 try:
#
# -> 3805     return self._engine.get_loc(casted_key)
#
#    3806 except KeyError as err:
#
#
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
#
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
#
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
#
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
#
#
# KeyError: 'gender'
#
#
#
# The above exception was the direct cause of the following exception:
#
#
#
# KeyError     Traceback (most recent call last)
#
# Cell In[19], line 2
#
#       1 ep.settings.set_figure_params(figsize=(4, 3), dpi=100)
#
# ----> 2 ep.pl.violin(adata, keys=["Age"], groupby="gender")
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\ehrapy\plot\_scanpy_pl_api.py:577, in violin(adata, keys, groupby, log, use_raw, stripplot, jitter, size, layer, scale, order, multi_panel, xlabel, ylabel, rotation, show, save, ax, **kwds)
#
#     507 """Violin plot.
#
#     508
#
#     509 Wraps :func:`seaborn.violinplot` for :class:`~anndata.AnnData`.
#
#    (...)    554     .. image:: /_static/docstring_previews/violin.png
#
#     555 """
#
#     556 violin_partial = partial(
#
#     557     sc.pl.violin,
#
#     558     keys=keys,
#
#    (...)    574     **kwds,
#
#     575 )
#
# --> 577 return violin_partial(adata=adata, groupby=groupby)
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\legacy_api_wrap\__init__.py:82, in legacy_api.<locals>.wrapper.<locals>.fn_compatible(*args_all, **kw)
#
#      79 @wraps(fn)
#
#      80 def fn_compatible(*args_all: P.args, **kw: P.kwargs) -> R:
#
#      81     if len(args_all) <= n_positional:
#
# ---> 82         return fn(*args_all, **kw)
#
#      84     args_pos: P.args
#
#      85     args_pos, args_rest = args_all[:n_positional], args_all[n_positional:]
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\scanpy\plotting\_anndata.py:861, in violin(***failed resolving arguments***)
#
#     859 obs_df = get.obs_df(adata, keys=[groupby] + keys, layer=layer, use_raw=use_raw)
#
#     860 if kwds.get("palette") is None:
#
# --> 861     if not isinstance(adata.obs[groupby].dtype, CategoricalDtype):
#
#     862         msg = (
#
#     863             f"The column `adata.obs[{groupby!r}]` needs to be categorical, "
#
#     864             f"but is of dtype {adata.obs[groupby].dtype}."
#
#     865         )
#
#     866         raise ValueError(msg)
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#
#    4100 if self.columns.nlevels > 1:
#
#    4101     return self._getitem_multilevel(key)
#
# -> 4102 indexer = self.columns.get_loc(key)
#
#    4103 if is_integer(indexer):
#
#    4104     indexer = [indexer]
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#
#    3807     if isinstance(casted_key, slice) or (
#
#    3808         isinstance(casted_key, abc.Iterable)
#
#    3809         and any(isinstance(x, slice) for x in casted_key)
#
#    3810     ):
#
#    3811         raise InvalidIndexError(key)
#
# -> 3812     raise KeyError(key) from err
#
#    3813 except TypeError:
#
#    3814     # If we have a listlike key, _check_indexing_error will raise
#
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#
#    3816     #  the TypeError.
#
#    3817     self._check_indexing_error(key)
#
#
#
# KeyError: 'gender'

# %%
ep.ad.infer_feature_types(adata2)
# Out:
# ! Features 'hospital_death', 'has_E87', 'has_J18', 'has_I50', 'has_N17', 'has_J96', 'has_E11', 'has_I25', 'has_E78', 'has_J98', 'has_Z51', 'has_I47', 'has_I10', 'has_D64', 'has_Z95', 'has_N18' were detected as categorical features stored numerically.Please verify and correct using `ep.ad.replace_feature_types` if necessary.
#  Detected feature types for AnnData object
# with 9864 obs and 25 vars
# ├── 📅 Date features
# ├── 📐 Numerical features
# │   ├── Age
# │   ├── hadm_id
# │   ├── los
# │   ├── stay_id
# │   └── subject_id
# └── 🗂️ Categorical features
#     ├── dod (4169 categories)
#     ├── ethnicity (33 categories)
#     ├── gender (2 categories)
#     ├── has_D64 (2 categories)
#     ├── has_E11 (2 categories)
#     ├── has_E78 (2 categories)
#     ├── has_E87 (2 categories)
#     ├── has_I10 (2 categories)
#     ├── has_I25 (2 categories)
#     ├── has_I47 (2 categories)
#     ├── has_I50 (2 categories)
#     ├── has_J18 (1 categories)
#     ├── has_J96 (2 categories)
#     ├── has_J98 (2 categories)
#     ├── has_N17 (2 categories)
#     ├── has_N18 (2 categories)
#     ├── has_Z51 (2 categories)
#     ├── has_Z95 (2 categories)
#     ├── hospital_death (2 categories)
#     └── insurance (6 categories)

# %%
ep.ad.correct_feature_types # use this to fix if feature types aren't correct

# %%
adata.obs_names
# Out:
# Index(['Cell_0', 'Cell_1', 'Cell_2',
#        'Cell_3', 'Cell_4', 'Cell_5',
#        'Cell_6', 'Cell_7', 'Cell_8',
#        'Cell_9',
#        ...
#        'Cell_9854', 'Cell_9855', 'Cell_9856',
#        'Cell_9857', 'Cell_9858', 'Cell_9859',
#        'Cell_9860', 'Cell_9861', 'Cell_9862',
#        'Cell_9863'],
#       dtype='object', length=9864)

# %%
TableOne(adata.obs, categorical=['gender', 'ethnicity', 'insurance'])
# Out:
# ----------------------------------------------
#
# KeyError     Traceback (most recent call last)
#
# Cell In[5], line 1
#
# ----> 1 TableOne(adata.obs, categorical=['gender', 'ethnicity', 'insurance'])
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\tableone\tableone.py:238, in TableOne.__init__(self, data, columns, categorical, continuous, groupby, nonnormal, min_max, pval, pval_adjust, htest_name, pval_test_name, htest, isnull, missing, ddof, labels, rename, sort, limit, order, remarks, label_suffix, decimals, smd, overall, row_percent, display_all, dip_test, normal_test, tukey_test, pval_threshold, include_null)
#
#     235 self.tables = Tables()
#
#     237 # Initialize attributes
#
# --> 238 data = self.initialize_core_attributes(data, columns, categorical, continuous, groupby,
#
#     239                                        nonnormal, min_max, pval, pval_adjust, htest_name,
#
#     240                                        htest, missing, ddof, rename, sort, limit, order,
#
#     241                                        label_suffix, decimals, smd, overall, row_percent,
#
#     242                                        dip_test, normal_test, tukey_test, pval_threshold,
#
#     243                                        include_null)
#
#     245 # Initialize intermediate tables
#
#     246 self.initialize_intermediate_tables()
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\tableone\tableone.py:322, in TableOne.initialize_core_attributes(self, data, columns, categorical, continuous, groupby, nonnormal, min_max, pval, pval_adjust, htest_name, htest, missing, ddof, rename, sort, limit, order, label_suffix, decimals, smd, overall, row_percent, dip_test, normal_test, tukey_test, pval_threshold, include_null)
#
#     319 self._warnings = {}
#
#     321 if self._categorical and self._include_null:
#
# --> 322     data[self._categorical] = handle_categorical_nulls(data[self._categorical])
#
#     324 self._groupbylvls = get_groups(data, self._groupby, self._order, self._reserved_columns)
#
#     326 return data
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#
#    4106     if is_iterator(key):
#
#    4107         key = list(key)
#
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#
#    4110 # take() does not accept boolean indexers
#
#    4111 if getattr(indexer, "dtype", None) == bool:
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#
#    6197 else:
#
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#
#    6202 keyarr = self.take(indexer)
#
#    6203 if isinstance(key, Index):
#
#    6204     # GH 42790 - Preserve name from an Index
#
#
#
# File c:\Users\Shauna\Documents\MIMIC-FINAL\.venv\Lib\site-packages\pandas\core\indexes\base.py:6249, in Index._raise_if_missing(self, key, indexer, axis_name)
#
#    6247 if nmissing:
#
#    6248     if nmissing == len(indexer):
#
# -> 6249         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#
#    6251     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
#    6252     raise KeyError(f"{not_found} not in index")
#
#
#
# KeyError: "None of [Index(['gender', 'ethnicity', 'insurance'], dtype='object')] are in the [columns]"
